# %% [markdown]
# # MCP Agent Template Playground
#
# Inspect the recovered skills and local MCP tools.

# %%
from pathlib import Path
from data_agent.config import REPO_ROOT
from data_agent.skills.loader import discover_skills
from data_agent.notebook import skills_cards, status_panel

# %%
skills = discover_skills(REPO_ROOT / "skills")
display(status_panel({"repository": str(REPO_ROOT), "skills": len(skills)}))
display(skills_cards(skills))
